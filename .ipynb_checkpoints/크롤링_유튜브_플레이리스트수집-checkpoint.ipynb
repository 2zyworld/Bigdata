# %%
# DeprecationWarning: executable_path has been deprecated, please pass in a Service object 에러
# !pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    return driver

# %%
import time
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import Request
import pandas as pd
import numpy as np

# %% [markdown]
# # 유튜브 플레이리스트 크롤링
# - 감정에 따라 검색어를 지정해서 플레이리스트를 수집하기엔 일일히 검색어를 입력해야하고 다양하게 수집이 불가할 거 같아
# - 플레이리스트 채널 구독자순위가 높은 채널링크에서 모든 영상을 수집하기로 함
#     - essential;
#     - https://www.youtube.com/c/essentialme/videos
#     - 나의 플레이리스트
#     - https://www.youtube.com/channel/UC2kPuCfWPDZhRg60gOdOlKg/videos
#     - 감성땅콩
#     - https://www.youtube.com/channel/UCvSWF-tYfSZTJs4bq3J9jXQ/videos
#     - 호정
#     - https://www.youtube.com/c/%ED%98%B8%EC%A0%95PLAYLIST/videos

# %% [markdown]
# ### 채널한개만 크롤링해보기
# - 찐막 JJINMAK 'https://www.youtube.com/channel/UC2kPuCfWPDZhRg60gOdOlKg/videos'

# %%
driver = set_chrome_driver()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\admin\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %%
driver.quit()

# %%
def channel_video_crawl(url):
    # 크롬 웹브라우저 실행
    driver.get(url)
    
    time.sleep(3)
    scroll = 5
    while scroll:
        driver.find_element_by_tag_name('body').send_keys(Keys.END) #end키 눌러서 스크롤내리기
        time.sleep(0.3)
        scroll -= 1
    
    # 해당 페이지 소스가져오기
    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')
    
    # 노래제목 가져오기
    all_title = soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')
    title = [soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')[n].text for n in range(0,len(all_title))]
    
    # url 가져오기
    link = [soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')[n]['href'] for n in range(0,len(all_title))]
    
    tag = []
    base_url = 'https://www.youtube.com'
    for i in link : 
        watch_url = base_url + i
        driver.get(watch_url)
        time.sleep(2)

        req = driver.page_source
        soup = BeautifulSoup(req, 'html.parser')

        tag.append(driver.find_element_by_css_selector('.style-scope ytd-video-primary-info-renderer').text.split('\n')[0])

    
    channel_video_df = pd.DataFrame({'title':title,'link':link,'tag':tag})
    
    print('수집된 영상링크 개수 : ',len(channel_video_df))
    
    return channel_video_df

# %%
channel_video_df = channel_video_crawl('https://www.youtube.com/channel/UC2kPuCfWPDZhRg60gOdOlKg/videos')
channel_video_df
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_17060/897118066.py:8: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END) #end키 눌러서 스크롤내리기
# C:\Users\admin\AppData\Local\Temp/ipykernel_17060/897118066.py:33: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   tag.append(driver.find_element_by_css_selector('.style-scope ytd-video-primary-info-renderer').text.split('\n')[0])
# 수집된 영상링크 개수 :  42
#                                                 title                  link  \
# 0                  우울한 날, 포근하게 안아주는 위로노래모음 | PLAYLIST  /watch?v=4xsser5_duU
# 1             힙한 하루🤟 적당히 둠칫한 힙합 & 알앤비 노래모음 | PLAYLIST  /watch?v=OiFTo6AkADU
# 2                   가정의 달👪 부모님 생각나는 가족노래모음 | PALYLIST  /watch?v=a2WXrPQE9UA
# ...

# %% [markdown]
# 이제 채널에 있는 동영상 링크를 하나씩 접속하며
# 동영상 페이지에서 가지고 있는 태그 추출

# %%
channel_video_df.to_csv('./crawl_data/youtube_channel_1.csv',  encoding='utf8')

# %%
watch_url = base_url + '/watch?v=4xsser5_duU'
driver.get(watch_url)

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')
# lis = soup.find_all('div',{'class':'style-scope ytd-app'})
# for li in lis :
#     tag = li.find('div','style-scope ytd-video-primary-info-renderer')
#     print(tag)
# for box in container :
#     print(box)
# container.find_all('yt-formatted-string','super-title style-scope ytd-video-primary-info-renderer')
# tag_box = soup.find_all('div','style-scope ytd-watch-metadata')
# tag_box = soup.find_all('yt-formatted-string','super-title style-scope ytd-video-primary-info-renderer')
tag = driver.find_element_by_css_selector('.style-scope ytd-video-primary-info-renderer').text.split('\n')[0]
# ['#우울한날 #슬픈노래 #힘들때듣기좋은노래', <- 0번인덱스만 추출
#  '우울한 날, 포근하게 안아주는 위로노래모음 | PLAYLIST',
#  '조회수 5,040회2022. 5. 12.',
#  '112',
#  '싫어요',
#  '공유',
#  '저장']
tag

# tag = [soup.find_all('yt-formatted-string','super-title style-scope ytd-video-primary-info-renderer')[n].text.replace("#","") for n in range(0,len(tag_box))]
# tag
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_17060/479479643.py:15: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   tag_box = driver.find_element_by_css_selector('.style-scope ytd-video-primary-info-renderer').text.split('\n')
# ['#우울한날 #슬픈노래 #힘들때듣기좋은노래',
#  '우울한 날, 포근하게 안아주는 위로노래모음 | PLAYLIST',
#  '조회수 5,040회2022. 5. 12.',
#  '112',
#  '싫어요',
#  '공유',
#  '저장']

# %%
channel_video_df['link']
# Out:
# 0     /watch?v=4xsser5_duU
# 1     /watch?v=OiFTo6AkADU
# 2     /watch?v=a2WXrPQE9UA
# 3     /watch?v=Vh0omXrlS5k
# 4     /watch?v=r6hnnDgXPvM
# 5     /watch?v=FbwBprHeLrQ
# 6     /watch?v=4WNJE9gq030
# 7     /watch?v=vh_JVKkpsL4
# 8     /watch?v=o-QxXe5kfoE
# 9     /watch?v=3FoJqr5pIS4
# 10    /watch?v=vVR03tYMvSk
# 11    /watch?v=EawahT8d6bQ
# 12    /watch?v=t0k3PlfD2q8
# 13    /watch?v=le6Chb97d8Y
# 14    /watch?v=9Lg9zBdscHs
# 15    /watch?v=MnTsGVO5KRA
# 16    /watch?v=uV0P2dw5LFU
# 17    /watch?v=PohCUb2sX7I
# 18    /watch?v=VaQ3mWkX8lw
# 19    /watch?v=sKAYnb5Wpxc
# 20    /watch?v=X2ju3_xodxc
# 21    /watch?v=50WTrXSs15w
# 22    /watch?v=o4EwjL_14xU
# 23    /watch?v=qa-crWmooEc
# 24    /watch?v=dSrjNOLa_N4
# 25    /watch?v=36H5KZ7YLN8
# 26    /watch?v=5Iz9gMi1Fjs
# 27    /watch?v=SPE5kQivFp8
# 28    /watch?v=762tHUGbmfk
# 29    /watch?v=50D81GNFgjw
# Name: link, dtype: object
