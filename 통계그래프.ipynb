# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

from math import pi
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

# %%
#랜덤 리스트 함수
result = []
    
def random_List(size):

    for v in range(size):
        
        result.append(random.randint(0, 100))
        
    return result

#동작 확인
result = random_List(8)
print(result)
# Out:
# [66, 61, 46, 98, 26, 7, 63, 86]
# <class 'int'>

# %%
# 랜덤의 8가지 감정 수치 생성
a = np.random.rand(15,8)
print(a)
print(type(a)) # <class 'numpy.ndarray'>
# Out:
# [[0.15793217 0.76845804 0.89244712 0.63736972 0.56671722 0.137361
#   0.8210202  0.33671887]
#  [0.14906586 0.95962848 0.10545905 0.44012498 0.25295059 0.49040268
#   0.50485361 0.18600695]
#  [0.2486408  0.05330162 0.36321937 0.01816157 0.29532037 0.65508983
#   0.32120156 0.61250845]
#  [0.53571183 0.68710392 0.10722811 0.4070657  0.13864834 0.42113276
#   0.64012013 0.93111621]
#  [0.87295969 0.02196921 0.30988668 0.90141579 0.38564654 0.30327679
#   0.26483135 0.94642387]
#  [0.57485123 0.20767835 0.83864585 0.95612297 0.53737381 0.65749778
#   0.93162647 0.67400443]
#  [0.74525712 0.06224553 0.36258352 0.67628057 0.98174211 0.99640641
#   0.93622428 0.25890724]
#  [0.36503174 0.30157324 0.86771155 0.42610748 0.02051139 0.07132825
#   0.86102254 0.892813  ]
#  [0.55198415 0.254205   0.17654173 0.41671946 0.16018536 0.13182584
#   0.82427453 0.37539298]
#  [0.37757099 0.36785435 0.08741979 0.46849667 0.76718391 0.67429093
#   0.13872803 0.94054582]
# ...

# %%
print(a * 100)
# Out:
# [[71.09524534 95.9836544  26.74424299 33.5001843  75.86575783 97.2375458
#   48.34844882  6.13265314]
#  [82.36009475  1.6172639  39.49706044 89.63198398  4.22004679 85.43203062
#   42.61389486 61.23493853]
#  [23.45097957 66.15132889 21.46213568 88.62216335  1.59805247 37.62393512
#   48.59722073 25.99370902]
#  [31.49822178 38.16197865  9.14800108 42.98673    38.34345794 76.0353199
#   49.45592108 54.37845556]
#  [57.35562827 70.30682501 19.95004266 65.44154197 54.26046711 28.84367417
#   89.53333192  2.06687708]]

# %%
senti = ['Anger.분노','Anticipation.기대','Joy.기쁨','Trust.신뢰','Fear.두려움','Surprise.놀라움','Sadness.슬픔','Disgust.혐오']
senti
# Out:
# ['Anger.분노',
#  'Anticipation.기대',
#  'Joy.기쁨',
#  'Trust.신뢰',
#  'Fear.두려움',
#  'Surprise.놀라움',
#  'Sadness.슬픔',
#  'Disgust.혐오']

# %%
df = pd.DataFrame(a*100, columns=senti)
len(df.columns)
df.columns
df[0:1]
df.iloc[[0,]]
df.index
df.iterrows()
pi

df
# Out:
#      Anger.분노  Anticipation.기대     Joy.기쁨   Trust.신뢰   Fear.두려움  Surprise.놀라움  \
# 0   15.793217        76.845804  89.244712  63.736972  56.671722     13.736100
# 1   14.906586        95.962848  10.545905  44.012498  25.295059     49.040268
# 2   24.864080         5.330162  36.321937   1.816157  29.532037     65.508983
# 3   53.571183        68.710392  10.722811  40.706570  13.864834     42.113276
# 4   87.295969         2.196921  30.988668  90.141579  38.564654     30.327679
# 5   57.485123        20.767835  83.864585  95.612297  53.737381     65.749778
# 6   74.525712         6.224553  36.258352  67.628057  98.174211     99.640641
# 7   36.503174        30.157324  86.771155  42.610748   2.051139      7.132825
# 8   55.198415        25.420500  17.654173  41.671946  16.018536     13.182584
# 9   37.757099        36.785435   8.741979  46.849667  76.718391     67.429093
# 10  92.023913        84.107070  38.546288  90.313519  58.710884     44.980719
# ...

# %%
df['user_id'] = ['user1','user1','user1','user2','user2','user3','user3','user3',
                 'user4','user5','user6','user7','user8','user9','user10']

df.columns[:-1]
df.index


row.user_id
df
# Out:
#      Anger.분노  Anticipation.기대     Joy.기쁨   Trust.신뢰   Fear.두려움  Surprise.놀라움  \
# 0   15.793217        76.845804  89.244712  63.736972  56.671722     13.736100
# 1   14.906586        95.962848  10.545905  44.012498  25.295059     49.040268
# 2   24.864080         5.330162  36.321937   1.816157  29.532037     65.508983
# 3   53.571183        68.710392  10.722811  40.706570  13.864834     42.113276
# 4   87.295969         2.196921  30.988668  90.141579  38.564654     30.327679
# 5   57.485123        20.767835  83.864585  95.612297  53.737381     65.749778
# 6   74.525712         6.224553  36.258352  67.628057  98.174211     99.640641
# 7   36.503174        30.157324  86.771155  42.610748   2.051139      7.132825
# 8   55.198415        25.420500  17.654173  41.671946  16.018536     13.182584
# 9   37.757099        36.785435   8.741979  46.849667  76.718391     67.429093
# 10  92.023913        84.107070  38.546288  90.313519  58.710884     44.980719
# ...

# %%
label = df.columns[:-1]
num_label = len(label)

# label_loc = np.linspace(start=0, stop=2*np.pi, num=len(data.columns))
angles = [x/float(num_label)*(2*pi) for x in range(num_label)] ## 각 등분점
angles += angles[:1] ## 시작점으로 다시 돌아와야하므로 시작점 추가

my_palette = plt.cm.get_cmap("Set2", len(df.index))

fig = plt.figure(figsize=(15,50))
fig.set_facecolor('white')

for i, row in df.iterrows():
    color = my_palette(i)
    data = df.iloc[i].drop('user_id').tolist()
    data += data[:1]
    
    ax = plt.subplot(8,2,i+1, polar=True)
    ax.set_theta_offset(pi / 2) ## 시작점
    ax.set_theta_direction(-1) ## 그려지는 방향 시계방향
    
    plt.xticks(angles[:-1], label, fontsize=13) ## x축 눈금 라벨
    ax.tick_params(axis='x', which='major', pad=15) ## x축과 눈금 사이에 여백을 준다.
 
    ax.set_rlabel_position(0) ## y축 각도 설정(degree 단위)
    plt.yticks([0,20,40,60,80,100],['0','2','4','6','8','10'], fontsize=10) ## y축 눈금 설정
    plt.ylim(0,100)
    
    ax.plot(angles, data, color=color, linewidth=2, linestyle='solid') ## 레이더 차트 출력
    ax.fill(angles, data, color=color, alpha=0.4) ## 도형 안쪽에 색을 채워준다.
    
    plt.title(row.user_id, size=20, color=color,x=-0.2, y=1.2, ha='left') ## 타이틀은 캐릭터 클래스로 한다.
 
plt.tight_layout(pad=1) ## subplot간 패딩 조절
plt.show()
