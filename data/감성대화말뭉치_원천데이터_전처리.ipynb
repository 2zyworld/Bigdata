# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('./data/감성대화말뭉치AI데이터_평가용Wave_대본1만문장.xlsx', engine='openpyxl')

# %%
df2 = pd.read_csv('./data/감정분류점수1.csv', encoding='cp949')

# %%
df1.head()
# Out:
#     연령  성별    상황키워드 감정_대분류 감정_소분류  \
# 0  청소년  남성  학업 및 진로     기쁨   감사하는
# 1  청소년  남성  학업 및 진로     기쁨   감사하는
# 2  청소년  남성  학업 및 진로     기쁨   감사하는
# 3  청소년  남성  학업 및 진로     기쁨   감사하는
# 4  청소년  남성  학업 및 진로     기쁨   감사하는
#
#                                              사람문장1  \
# 0        오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1             오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2        오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3  오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4         나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.
#
#                                         기계문장1  \
# 0                 오늘 바라던 반장이 되셨군요. 정말 기쁘시겠어요.
# 1  오늘 시험을 잘 보셔서 기쁘시군요. 친구에겐 뭐라고 고마움을 표시할 건가요?
# 2               오늘 대학 합격 소식을 듣게 되어 정말 기쁘시겠어요.
# 3                      졸업식에 선생님을 못 뵈어 아쉬웠겠어요.
# 4            그동안 고생했는데 금상 수상까지 하셔서 정말 기쁘시겠어요.
#
#                                                사람문장2  \
# 0                           친구들에게 어떻게 보답하면 좋을지 고민이야.
# ...

# %%
df1.tail()
# Out:
#       연령  성별  상황키워드 감정_대분류       감정_소분류  \
# 9995  노년  남성     재정     슬픔      환멸을 느끼는
# 9996  노년  남성  건강,죽음     상처         충격받은
# 9997  노년  남성     재정     불안        걱정스러운
# 9998  노년  여성  건강,죽음     불안          두려운
# 9999  노년  남성     재정     당황  남의 시선을 의식하는
#
#                                                   사람문장1  \
# 9995               소득이 너무 적어서 제대로 된 노후 대책을 할 수가 없어 힘들어.
# 9996      요즘 두통이 잦았는데 결국 이런 일이 생겼네. 난 건강한 줄 알았는데 충격받았어.
# 9997  친구가 돈이 행복의 전부가 아니라고 하더니 노후 준비를 전혀 안 한 거야. 어휴 정...
# 9998                   아들이 갑자기 찾아왔는데 손자가 희귀병이래. 너무 두려워.
# 9999            친구들에게는 자식이 선물해 줬다고 했지만 사실은 다 내가 구입한 거야.
#
#                                     기계문장1  \
# 9995  적은 소득 때문에 제대로 된 노후 대책을 하는 게 어려우시군요.
# 9996           무슨 일인지 조금 더 자세히 말씀해 주시겠어요?
# 9997     친구가 노후 준비를 전혀 안 해서 걱정스러운 마음이시군요.
# 9998               손자가 희귀병이어서 무척 두려우시겠어요.
# 9999                친구들에게 사실대로 말하지 못하셨군요.
#
#                                           사람문장2  \
# 9995        백세시대라 노후를 잘 대비해야 하는데 걱정이 이만저만이 아니야.
# ...

# %%
df3=df1.replace({'감정_소분류':'혼란스러운(당황한)'},{'감정_소분류':'혼란스러운'})

# %%
df3.head()
# Out:
#     연령  성별    상황키워드 감정_대분류 감정_소분류  \
# 0  청소년  남성  학업 및 진로     기쁨   감사하는
# 1  청소년  남성  학업 및 진로     기쁨   감사하는
# 2  청소년  남성  학업 및 진로     기쁨   감사하는
# 3  청소년  남성  학업 및 진로     기쁨   감사하는
# 4  청소년  남성  학업 및 진로     기쁨   감사하는
#
#                                              사람문장1  \
# 0        오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1             오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2        오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3  오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4         나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.
#
#                                         기계문장1  \
# 0                 오늘 바라던 반장이 되셨군요. 정말 기쁘시겠어요.
# 1  오늘 시험을 잘 보셔서 기쁘시군요. 친구에겐 뭐라고 고마움을 표시할 건가요?
# 2               오늘 대학 합격 소식을 듣게 되어 정말 기쁘시겠어요.
# 3                      졸업식에 선생님을 못 뵈어 아쉬웠겠어요.
# 4            그동안 고생했는데 금상 수상까지 하셔서 정말 기쁘시겠어요.
#
#                                                사람문장2  \
# 0                           친구들에게 어떻게 보답하면 좋을지 고민이야.
# ...

# %%
df4=df3.replace({'감정_소분류':'고립된(당황한)'},{'감정_소분류':'고립된'})

# %%
df5=df4.replace({'감정_소분류':'구역질나는'},{'감정_소분류':'구역질 나는'})

# %%
df6=df5.replace({'감정_소분류':'가난한, 불우한'},{'감정_소분류':'불우한'})

# %%
df7=df6.replace({'감정_소분류':'스트레스받는'},{'감정_소분류':'스트레스 받는'})

# %%
df8=df7.replace({'감정_소분류':'충격받은'},{'감정_소분류':'충격 받은'})

# %%
df8.head()
# Out:
#     연령  성별    상황키워드 감정_대분류 감정_소분류  \
# 0  청소년  남성  학업 및 진로     기쁨   감사하는
# 1  청소년  남성  학업 및 진로     기쁨   감사하는
# 2  청소년  남성  학업 및 진로     기쁨   감사하는
# 3  청소년  남성  학업 및 진로     기쁨   감사하는
# 4  청소년  남성  학업 및 진로     기쁨   감사하는
#
#                                              사람문장1  \
# 0        오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1             오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2        오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3  오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4         나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.
#
#                                         기계문장1  \
# 0                 오늘 바라던 반장이 되셨군요. 정말 기쁘시겠어요.
# 1  오늘 시험을 잘 보셔서 기쁘시군요. 친구에겐 뭐라고 고마움을 표시할 건가요?
# 2               오늘 대학 합격 소식을 듣게 되어 정말 기쁘시겠어요.
# 3                      졸업식에 선생님을 못 뵈어 아쉬웠겠어요.
# 4            그동안 고생했는데 금상 수상까지 하셔서 정말 기쁘시겠어요.
#
#                                                사람문장2  \
# 0                           친구들에게 어떻게 보답하면 좋을지 고민이야.
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0  category      anger  Anticipation   Joy  Trust  Fear  Surprise  \
# 0           1  가난한, 불우한  16.666667           0.0   0.0    0.0  30.0      17.5
# 1           2      감사하는   0.000000           2.5  57.5   85.0   0.0      22.5
# 2           3     걱정스러운   7.500000          45.0   0.0    0.0  62.5      15.0
# 3           4       고립된   7.500000          12.5   0.0    0.0  55.0      17.5
# 4           5     괴로워하는  20.000000           0.0   0.0    0.0  42.5      17.5
#
#    Sadness  Disgust
# 0     57.5     25.0
# 1      0.0      0.0
# 2     25.0     12.5
# 3     15.0     12.5
# 4     70.0     35.0

# %%
df2=df2.replace({'category':'가난한, 불우한'},{'category':'불우한'})

# %%
df2.head()
# Out:
#    Unnamed: 0 category      anger  Anticipation   Joy  Trust  Fear  Surprise  \
# 0           1      불우한  16.666667           0.0   0.0    0.0  30.0      17.5
# 1           2     감사하는   0.000000           2.5  57.5   85.0   0.0      22.5
# 2           3    걱정스러운   7.500000          45.0   0.0    0.0  62.5      15.0
# 3           4      고립된   7.500000          12.5   0.0    0.0  55.0      17.5
# 4           5    괴로워하는  20.000000           0.0   0.0    0.0  42.5      17.5
#
#    Sadness  Disgust
# 0     57.5     25.0
# 1      0.0      0.0
# 2     25.0     12.5
# 3     15.0     12.5
# 4     70.0     35.0

# %%
# 데이터 일부분만 사용
data1 = df8[['감정_소분류','사람문장1','사람문장2','사람문장3']]

# %%
data1.rename(columns={'감정_소분류':'category'}, inplace=True)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data2 = df2[['category','anger','Anticipation','Joy','Trust','Fear','Surprise','Sadness','Disgust']]

# %%
data1.head()
# Out:
#   category                                            사람문장1  \
# 0     감사하는        오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1     감사하는             오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2     감사하는        오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3     감사하는  오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4     감사하는         나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.
#
#                                                사람문장2  \
# 0                           친구들에게 어떻게 보답하면 좋을지 고민이야.
# 1                                       말로 하기 쑥스러운데.
# 2  사실 이렇게 대학에 들어갈 수 있게 된 것도 엄마 덕분이야. 나 때문에 고생 많이 ...
# 3  그동안 말썽도 많이 피웠는데 한 번도 크게 화내신 적이 없었어. 졸업식에서야 선생님...
# 4  근데 친구들이 없었다면 못 했을 거야. 대회장에서 처음부터 끝까지 응원해 줘서 너무...
#
#                                         사람문장3
# 0  친구 한 명씩 찾아가서 고맙다고 말하고 바라는 점을 물어보면 좋을 것 같아.
# 1                     같이 떡볶이 먹고 피시방 가자고 해야겠어.
# 2             오늘은 내가 설거지랑 청소를 해야겠어. 사랑한다는 말도.
# 3                     너무 감사했다고 지금 문자라도 보내야겠어.
# 4                       내일 저녁에 빕스에서 저녁을 살 거야.

# %%
data1.tail(50)
# Out:
#          category                                              사람문장1  \
# 9950          희생된                                 가족들을 위해서 헌신하며 살았어.
# 9951          희생된                        만성질환에 재정이 안 좋다 보니 치료가 걱정이다.
# 9952          희생된                       요즘 자녀 세대는 자리 잡기가 너무 힘든 거 같아.
# 9953          희생된      내 지원금으로 친구 입원비를 대신 내줬어. 앞으로는 내줄 수 가 없을 텐데 걱정돼
# 9954          희생된                                     영화를 보며 한참 울었어.
# 9955          희생된                                         건강을 다 잃었어.
# 9956          희생된                                    건강적으로 희생된 기분이야.
# 9957          희생된                         그렇게 나를 힘들게 하던 시어머니가 돌아가셨어.
# 9958          희생된                           이 회사에서 일하고 나는 심장질환을 얻었어.
# 9959          희생된                     아들이 많이 아파서 내일 내 간을 이식해 주기로 했어.
# 9960          희생된                평생 가족을 위해 희생했는데 이제 남은건 여러가지 병들 뿐이야.
# 9961          희생된                          평생 일한다고 건강 못챙기고 이 나이가 됐네.
# 9962          희생된                자식들을 다 키우고 나니 내게는 남은 게 없는 기분이라 상처야.
# ...

# %%
data2.head()
# Out:
#   category      anger  Anticipation   Joy  Trust  Fear  Surprise  Sadness  \
# 0      불우한  16.666667           0.0   0.0    0.0  30.0      17.5     57.5
# 1     감사하는   0.000000           2.5  57.5   85.0   0.0      22.5      0.0
# 2    걱정스러운   7.500000          45.0   0.0    0.0  62.5      15.0     25.0
# 3      고립된   7.500000          12.5   0.0    0.0  55.0      17.5     15.0
# 4    괴로워하는  20.000000           0.0   0.0    0.0  42.5      17.5     70.0
#
#    Disgust
# 0     25.0
# 1      0.0
# 2     12.5
# 3     12.5
# 4     35.0

# %%
data3 = data1[['category','사람문장1']]

# %%
data4 = data1[['category','사람문장2']]

# %%
data5 = data1[['category','사람문장3']]

# %%
data3.rename(columns={'사람문장1':'text'}, inplace=True)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data4.rename(columns={'사람문장2':'text'}, inplace=True)

# %%
data5.rename(columns={'사람문장3':'text'}, inplace=True)

# %%
data3.head()
# Out:
#   category                                             text
# 0     감사하는        오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1     감사하는             오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2     감사하는        오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3     감사하는  오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4     감사하는         나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.

# %%
data4.head()
# Out:
#   category                                               text
# 0     감사하는                           친구들에게 어떻게 보답하면 좋을지 고민이야.
# 1     감사하는                                       말로 하기 쑥스러운데.
# 2     감사하는  사실 이렇게 대학에 들어갈 수 있게 된 것도 엄마 덕분이야. 나 때문에 고생 많이 ...
# 3     감사하는  그동안 말썽도 많이 피웠는데 한 번도 크게 화내신 적이 없었어. 졸업식에서야 선생님...
# 4     감사하는  근데 친구들이 없었다면 못 했을 거야. 대회장에서 처음부터 끝까지 응원해 줘서 너무...

# %%
data5.tail(50)
# Out:
#          category                                            text
# 9950          희생된                                             NaN
# 9951          희생된                                             NaN
# 9952          희생된                                             NaN
# 9953          희생된                              모르겠어. 방법이 떠오르지 않아.
# 9954          희생된            나라면 그렇게 할 수 있을까 생각해 보게 되는 감동적인 영화였어.
# 9955          희생된                                     관절이 너무 불편해.
# 9956          희생된                            어릴적부터 너무 공사장에서만 일했어.
# 9957          희생된                                             NaN
# 9958          희생된                                             NaN
# 9959          희생된                                             NaN
# 9960          희생된                                             NaN
# 9961          희생된                                             NaN
# 9962          희생된                     앞으로는 내게 집중할 수 있는 취미를 가져야겠어.
# ...

# %%
data5=data5.dropna(axis=0)

# %%
data5.tail(50)
# Out:
#          category                                            text
# 9934          희생된    자식들 키우고 교육 등 과한 노력을 쏟다 보니 부모들은 고생만 해서 그런가 봐.
# 9940          희생된            일을 하면서 배우는 것도 있고 다 했을 때 좀 뿌듯하기도 하더라.
# 9941          희생된                                 아내와 상의를 해 봐야겠어.
# 9942          희생된                             해결 방법을 가족들과 찾아볼 거야.
# 9943          희생된        맞아. 혼자 너무 고민할 것이 아니라 의사든 누구든 상담 좀 받아야겠어.
# 9947          희생된                         게임이나 하면 조금은 좋은데 그게 그거야!
# 9948          희생된   자식들 키우고 아버지 병원비에 생활비를 내다 보니 제 노후는 전혀 준비를 못했네.
# 9949          희생된                      질환이 생기기 전에 다양한 취미생활을 할까 해.
# 9953          희생된                              모르겠어. 방법이 떠오르지 않아.
# 9954          희생된            나라면 그렇게 할 수 있을까 생각해 보게 되는 감동적인 영화였어.
# 9955          희생된                                     관절이 너무 불편해.
# 9956          희생된                            어릴적부터 너무 공사장에서만 일했어.
# 9962          희생된                     앞으로는 내게 집중할 수 있는 취미를 가져야겠어.
# ...

# %%
result1=pd.merge(data2, data3, on='category', how='left')

# %%
result1.head()
# Out:
#   category      anger  Anticipation  Joy  Trust  Fear  Surprise  Sadness  \
# 0      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 1      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 2      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 3      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 4      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
#
#    Disgust                                              text
# 0     25.0  우리 집이 잘 못산다는 것을 친구들이 알게 되었을 때 정말 억장이 무너지는 것 같았어.
# 1     25.0     학급비를 내지 못하고 있을 때 친구들에게 따돌림을 당할까봐 심장이 조마조마 했어.
# 2     25.0                부모님의 지갑을 보고 나니 체험학습 비 달라는 말을 못하겠어.
# 3     25.0              우리 집이 불우한 것이 친구들 사이에선 놀림거리로 여겨지고 있어.
# 4     25.0          내가 돈이 없는 것으로 인해 따돌림 당한다는 사실을 부모님이 알아버리셨어

# %%
result2=pd.merge(data2, data4, on='category', how='left')

# %%
result3=pd.merge(data2, data5, on='category', how='left')

# %%
result2.head()
# Out:
#   category      anger  Anticipation  Joy  Trust  Fear  Surprise  Sadness  \
# 0      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 1      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 2      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 3      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 4      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
#
#    Disgust                                               text
# 0     25.0             창피해서 친구들과 마주하고 싶지 않아. 날 보고 수군거릴 것만 같아.
# 1     25.0                        돈이 없어서 학급비를 못 낸다는 게 너무 비참해.
# 2     25.0  집안 사정이 좋지 않아서 체험학습비가 필요하다고 말씀드려야 하는데 입이 떨어지질 않더라.
# 3     25.0                            너무 속상해서 친구들을 안보고 살고 싶어.
# 4     25.0                      많이 속상해 하시고 나한테 미안해서 어쩔 줄 모르셔.

# %%
result3.tail()
# Out:
#      category  anger  Anticipation  Joy  Trust  Fear  Surprise  Sadness  \
# 8609      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8610      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8611      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8612      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8613      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
#
#       Disgust                                            text
# 8609     25.0                                  딸과 전화통화를 해야겠어.
# 8610     25.0                             가족들에게 솔직하게 말해 봐야겠어.
# 8611     25.0                              남편에게 솔직하게 말해 봐야겠어.
# 8612     25.0  나보다 더 아픈 남편도 있는데 내가 그러면 안 된다고 스스로 다독이면 괜찮을 거야.
# 8613     25.0        딸에게 사랑한다고 말할 거야. 같이 외출도 해서 기분 전환을 하고 싶어.

# %%
result=pd.concat([result1, result2,result3], axis = 0)

# %%
result.head()
# Out:
#   category      anger  Anticipation  Joy  Trust  Fear  Surprise  Sadness  \
# 0      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 1      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 2      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 3      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
# 4      불우한  16.666667           0.0  0.0    0.0  30.0      17.5     57.5
#
#    Disgust                                              text
# 0     25.0  우리 집이 잘 못산다는 것을 친구들이 알게 되었을 때 정말 억장이 무너지는 것 같았어.
# 1     25.0     학급비를 내지 못하고 있을 때 친구들에게 따돌림을 당할까봐 심장이 조마조마 했어.
# 2     25.0                부모님의 지갑을 보고 나니 체험학습 비 달라는 말을 못하겠어.
# 3     25.0              우리 집이 불우한 것이 친구들 사이에선 놀림거리로 여겨지고 있어.
# 4     25.0          내가 돈이 없는 것으로 인해 따돌림 당한다는 사실을 부모님이 알아버리셨어

# %%
result.tail()
# Out:
#      category  anger  Anticipation  Joy  Trust  Fear  Surprise  Sadness  \
# 8609      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8610      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8611      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8612      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
# 8613      희생된   12.5           0.0  0.0    0.0  40.0      22.5     82.5
#
#       Disgust                                            text
# 8609     25.0                                  딸과 전화통화를 해야겠어.
# 8610     25.0                             가족들에게 솔직하게 말해 봐야겠어.
# 8611     25.0                              남편에게 솔직하게 말해 봐야겠어.
# 8612     25.0  나보다 더 아픈 남편도 있는데 내가 그러면 안 된다고 스스로 다독이면 괜찮을 거야.
# 8613     25.0        딸에게 사랑한다고 말할 거야. 같이 외출도 해서 기분 전환을 하고 싶어.

# %%
result_r = result[['category','text','anger','Anticipation','Joy','Trust','Fear','Surprise','Sadness','Disgust']]

# %%
result_r.head()
# Out:
#   category                                              text      anger  \
# 0      불우한  우리 집이 잘 못산다는 것을 친구들이 알게 되었을 때 정말 억장이 무너지는 것 같았어.  16.666667
# 1      불우한     학급비를 내지 못하고 있을 때 친구들에게 따돌림을 당할까봐 심장이 조마조마 했어.  16.666667
# 2      불우한                부모님의 지갑을 보고 나니 체험학습 비 달라는 말을 못하겠어.  16.666667
# 3      불우한              우리 집이 불우한 것이 친구들 사이에선 놀림거리로 여겨지고 있어.  16.666667
# 4      불우한          내가 돈이 없는 것으로 인해 따돌림 당한다는 사실을 부모님이 알아버리셨어  16.666667
#
#    Anticipation  Joy  Trust  Fear  Surprise  Sadness  Disgust
# 0           0.0  0.0    0.0  30.0      17.5     57.5     25.0
# 1           0.0  0.0    0.0  30.0      17.5     57.5     25.0
# 2           0.0  0.0    0.0  30.0      17.5     57.5     25.0
# 3           0.0  0.0    0.0  30.0      17.5     57.5     25.0
# 4           0.0  0.0    0.0  30.0      17.5     57.5     25.0

# %%
result_r.tail(50)
# Out:
#      category                                               text  anger  \
# 8564      희생된                          차를 못사서 아쉽지만 아이를 생각하면 괜찮아.   12.5
# 8565      희생된                          친구들도 다들 바쁘고 나랑 다 비슷한 처지라.   12.5
# 8566      희생된  무뚝뚝한 편이라 대화할 시간을 많이 갖지 못했는데 여행 시간을 통해서 서로의 마음을...   12.5
# 8567      희생된                           가끔은 나만 희생하는 것 같은 생각이 들어.   12.5
# 8568      희생된                              가족들과 깊은 대화를 한번 해봐야겠어.   12.5
# 8569      희생된                    미안함과 고마움을 담아서 멋진 식사라도 대접해주고 싶네.   12.5
# 8570      희생된              아내와 앞으로 어떻게 하면 좋을지에 대해서 서로 얘기를 해봐야겠어.   12.5
# 8571      희생된       작은 선물이라도 하나 사서 아내를 위로해주고 아내가 기뻐하는 모습을 보고 싶어.   12.5
# 8572      희생된   건강하지 못한 아들을 보면 안쓰럽고 미안하지. 그래도 힘들지만 잘 이겨낼 거라고 믿어.   12.5
# 8573      희생된  다른 가족들이랑 상의해보려고 해. 적어도 구역질 나는 감정은 없어야지 내가 살 수 ...   12.5
# 8574      희생된  간병인 쓰면서 하자니까 그건 싫다며 내 일까지 그만두고 나보고 하래. 자기들이 하던...   12.5
# 8575      희생된                                               명상해.   12.5
# ...

# %%
print(result_r)
# Out:
#      category                                              text      anger  \
# 0         불우한  우리 집이 잘 못산다는 것을 친구들이 알게 되었을 때 정말 억장이 무너지는 것 같았어.  16.666667
# 1         불우한     학급비를 내지 못하고 있을 때 친구들에게 따돌림을 당할까봐 심장이 조마조마 했어.  16.666667
# 2         불우한                부모님의 지갑을 보고 나니 체험학습 비 달라는 말을 못하겠어.  16.666667
# 3         불우한              우리 집이 불우한 것이 친구들 사이에선 놀림거리로 여겨지고 있어.  16.666667
# 4         불우한          내가 돈이 없는 것으로 인해 따돌림 당한다는 사실을 부모님이 알아버리셨어  16.666667
# ...       ...                                               ...        ...
# 8609      희생된                                    딸과 전화통화를 해야겠어.  12.500000
# 8610      희생된                               가족들에게 솔직하게 말해 봐야겠어.  12.500000
# 8611      희생된                                남편에게 솔직하게 말해 봐야겠어.  12.500000
# 8612      희생된    나보다 더 아픈 남편도 있는데 내가 그러면 안 된다고 스스로 다독이면 괜찮을 거야.  12.500000
# 8613      희생된          딸에게 사랑한다고 말할 거야. 같이 외출도 해서 기분 전환을 하고 싶어.  12.500000
#
#       Anticipation  Joy  Trust  Fear  Surprise  Sadness  Disgust
# ...

# %%
result_r.to_excel('./감성대화말뭉치_원천데이터_전처리1.xlsx')

# %%
result_r.to_csv('./감성대화말뭉치_원천데이터_전처리1.csv',encoding='utf-8-sig')
